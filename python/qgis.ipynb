# %%
import os
from qgis.core import *
from qgis.gui import *
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
path_to_tif = "../dataGdals/LaiParamOneCycle_2007_gdals.tif"

# %%
# Initialize QGIS Application
# Supply the path to the qgis install location
QgsApplication.setPrefixPath("/data/Database/Miniconda3/bin/qgis", True)
# Create a reference to the QgsApplication.
# Setting the second argument to True enables the GUI. We need
# this since this is a custom application.
qgs = QgsApplication([], False)

# load providers
qgs.initQgis()

# Finally, exitQgis() is called to remove the
# provider and layer registries from memory
# qgs.exitQgis()

# %%
my_raster_layer = QgsRasterLayer(path_to_tif, "my layer")

# %%
iface.addRasterLayer(path_to_tif, "layer name you like")

# %%
import geopandas as gpd

# 从矢量文件创建QGIS图层
# chongqing = QgsVectorLayer('../dataGdals/landcover_2007_gdals.shp')

gpd.read_file('../dataGdals/landcover_2007_gdals.shp').plot()
# gpd.read_file('../dataGdals/LaiParamOneCycle_2007_gdals.tif').plot()
plt.show()

# %%
from qgis.PyQt.QtWidgets import QApplication

# %%
QgsApplication.prefixPath()
# Out:
# ''
